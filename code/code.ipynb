# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Charger le fichier CSV
data = pd.read_csv(r"C:\Users\user\Desktop\python-projct\StudentsPerformance.csv")

# Afficher les 5 premières lignes
print(data.head())
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.shape
# Out:
# (1000, 14)

# %%
data.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
import pandas as pd

# Charger le dataset CSV
data = pd.read_csv(r"C:\Users\user\Desktop\python-projct\StudentsPerformance.csv")

# Afficher le nombre de valeurs nulles par colonne
print("Nombre de valeurs nulles par colonne :")
print(data.isnull().sum())
# Out:
# Nombre de valeurs nulles par colonne :
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
# visualiser le nmbr de mal et female dans le dataset 
plt.subplots(figsize=(5,5))
data['gender'].value_counts(normalize = True)
data['gender'].value_counts(dropna = False).plot.bar(color = 'cyan')
plt.title('Comparison of Males and Females')
plt.xlabel('gender')
plt.ylabel('count')
plt.show()

# %%
# visualiser les deff groupes dans le dataset 
plt.subplots(figsize=(15,5))
data['race/ethnicity'].value_counts(normalize = True)
data['race/ethnicity'].value_counts(dropna = False).plot.bar(color=['black', 'red', 'green', 'blue', 'cyan'])
plt.title('Comparison of various groups')
plt.xlabel('Groups')
plt.ylabel('count')
plt.show()

# %%
# Preparer le datset 
df = data.groupby('race/ethnicity').size()

# executer le pilot pandas pour afficher les groupe de ce dataset 
df.plot(kind='pie', subplots=True, figsize=(15, 8))
plt.title("Pie Chart of Vehicle Class - Bad")
plt.ylabel("")
plt.show()

# %%
# visualiser les notes de math 
plt.subplots(figsize=(15,5))
data['math score'].value_counts(normalize = True)
data['math score'].value_counts(dropna = False).plot.bar(figsize = (18, 10))
plt.title('Comparison of math scores')
plt.xlabel('Maths Marks / score')
plt.ylabel('count')
plt.show()

# %%
# visualiser le score de lecture  
plt.subplots(figsize=(15,5))
data['reading score'].value_counts(normalize = True)
data['reading score'].value_counts(dropna = False).plot.bar(figsize = (18, 10), color = 'orange')
plt.title('Comparison of Reading Scores')
plt.xlabel('Reading Marks / Score')
plt.ylabel('Sount')
plt.show()

# %%
# visualiser le score d'ecriture 
plt.subplots(figsize=(15,5))
data['writing score'].value_counts(normalize = True)
data['writing score'].value_counts(dropna = False).plot.bar(figsize = (18, 10), color = 'green')
plt.title('Comparison of Writing scores')
plt.xlabel('Writing marks / Score')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize = (16,5))

plt.subplot(1, 3, 1)
sns.distplot(data['math score'])

plt.subplot(1, 3, 2)
sns.distplot(data['reading score'])

plt.subplot(1, 3, 3)
sns.distplot(data['writing score'])

plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_22796\138431772.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['math score'])
# C:\Users\user\AppData\Local\Temp\ipykernel_22796\138431772.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
#Afficher les etudient reusit et nn en maths
plt.subplots(figsize=(15,8))
passmarks = 40

data['pass_math'] = np.where(data['math score']< passmarks, 'Fail', 'Pass')
data['pass_math'].value_counts(dropna = False).plot.bar(color = 'black', figsize = (5, 3))

plt.title('Comparison of students passed or failed in maths')
plt.xlabel('status')
plt.ylabel('count')
plt.show()

# %%
data['pass_reading'] = np.where(data['reading score']< passmarks, 'Fail', 'Pass')
data['pass_reading'].value_counts(dropna = False).plot.bar(color = 'brown', figsize = (5, 3))

plt.title('Comparison of students passed or failed in maths')
plt.xlabel('status')
plt.ylabel('count')
plt.show()

# %%
data['pass_writing'] = np.where(data['writing score']< passmarks, 'Fail', 'Pass')
data['pass_writing'].value_counts(dropna = False).plot.bar(color = 'blue', figsize = (5, 3))

plt.title('Comparison of students passed or failed in maths')
plt.xlabel('status')
plt.ylabel('count')
plt.show()

# %%
# vesialiser tous les scores de tous les etudients 
plt.subplots(figsize=(15,8))
data['total_score'] = data['math score'] + data['reading score'] + data['writing score']

data['total_score'].value_counts(normalize = True)
data['total_score'].value_counts(dropna = True).plot.bar(color = 'cyan', figsize = (40, 8))

plt.title('comparison of total score of all the students')
plt.xlabel('total score scored by the students')
plt.ylabel('count')
plt.show()

# %%
from math import * 

data['percentage'] = data['total_score']/3

for i in range(0, 1000):
  data['percentage'][i] = ceil(data['percentage'][i])

data['percentage'].value_counts(normalize = True)
data['percentage'].value_counts(dropna = False).plot.bar(figsize = (16, 8), color = 'red')

plt.title('Comparison of percentage scored by all the students')
plt.xlabel('percentage score')
plt.ylabel('count')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_22796\2418252462.py:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['percentage'][i] = ceil(data['percentage'][i])
# ...

# %%
# vérifier quel élève est en échec global (cad il passe pas )

data['status'] = data.apply(lambda x : 'Fail' if x['math score'] == 'Fail' or 
                           x['reading score'] == 'Fail' or x['writing score'] == 'Fail'
                           else 'pass', axis = 1)

data['status'].value_counts(dropna = False).plot.bar(color = 'gray', figsize = (5, 5))
plt.title('overall results')
plt.xlabel('status')
plt.ylabel('count')
plt.show()

# %%
# Assigning grades to the grades according to the following criteria :
# 0  - 40 marks : grade E fail 
# 41 - 60 marks : grade D moyenne 
# 60 - 70 marks : grade C normal
# 70 - 80 marks : grade B bien 
# 80 - 90 marks : grade A ca va 
# 90 - 100 marks : grade O excelent
def getgrade(percentage, status):
  if status == 'Fail':
    return 'E'
  if(percentage >= 90):
    return 'O'
  if(percentage >= 80):
    return 'A'
  if(percentage >= 70):
    return 'B'
  if(percentage >= 60):
    return 'C'
  if(percentage >= 40):
    return 'D'
  else :
    return 'E'
data['grades'] = data.apply(lambda x: getgrade(x['percentage'], x['status']), axis = 1 )

data['grades'].value_counts()
# Out:
# grades
# B    260
# C    252
# D    223
# A    156
# O     58
# E     51
# Name: count, dtype: int64

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score pass_math  \
# 0                    none          72             72             74      Pass
# 1               completed          69             90             88      Pass
# 2                    none          90             95             93      Pass
# 3                    none          47             57             44      Pass
# 4                    none          76             78             75      Pass
#
#   pass_reading pass_writing  total_score  percentage status grades
# ...

# %%
# comparer de degrer de reusite entre les male et female 

plt.subplots(figsize=(15,8))
sns.countplot(x = data['grades'], data = data, hue = data['gender'], palette = 'cubehelix')

plt.show()

# %%
# Convertir les colonnes catégoriques en indicateurs (dummy variables)
encoded_data = pd.get_dummies(data)

# Créer la heatmap
plt.rcParams['figure.figsize'] = (15, 15)
sns.heatmap(encoded_data.corr(), cmap='rainbow', annot=True)
plt.title('Correlations between the attributes', fontsize=20)
#afficher la matrice de correlations 
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Charger le fichier CSV
data = pd.read_csv(r"C:\Users\user\Desktop\python-projct\StudentsPerformance.csv")

# Afficher les 5 premières lignes data set 
print(data.head())
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# prétraitement de la dataset 
from sklearn.preprocessing import LabelEncoder


le = LabelEncoder()
#encodage d'étiquette pour le  préparer aux tests 
data['test preparation course'] = le.fit_transform(data['test preparation course'])


data['lunch'] = le.fit_transform(data['lunch'])

# %%
# grouper les races de cette dataset chaque groupe a un nmbr 1 2 3 4 5
data['race/ethnicity'] = data['race/ethnicity'].replace('group A', 1)
data['race/ethnicity'] = data['race/ethnicity'].replace('group B', 2)
data['race/ethnicity'] = data['race/ethnicity'].replace('group C', 3)
data['race/ethnicity'] = data['race/ethnicity'].replace('group D', 4)
data['race/ethnicity'] = data['race/ethnicity'].replace('group E', 5)
#afficher chaque type avec sont nmbr  
data['race/ethnicity'].value_counts()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13712\2292523244.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['race/ethnicity'] = data['race/ethnicity'].replace('group E', 5)
# race/ethnicity
# 3    319
# 4    262
# 2    190
# 5    140
# 1     89
# Name: count, dtype: int64

# %%
#afficher chaque type des parents avec sonts nmbrs 
data['parental level of education'] = le.fit_transform(data['parental level of education'])
data['parental level of education'].value_counts()
# Out:
# parental level of education
# 4    226
# 0    222
# 2    196
# 5    179
# 1    118
# 3     59
# Name: count, dtype: int64

# %%
data['gender'] = le.fit_transform(data['gender'])

# faire les étiquette pour la colone score math 
data['math score'] = le.fit_transform(data['math score'])

# faire les étiquette pour la colone score de lecture
data['reading score'] = le.fit_transform(data['reading score'])

# faire les étiquette pour la colone score de lecriture 

data['writing score'] = le.fit_transform(data['writing score'])
# faire les étiquette pour la colone de la carte de déjeuner 
data['lunch'] = le.fit_transform(data['lunch'])

# %%
x = data.iloc[:,:14]
y = data.iloc[:,:14]

print(x.shape)
print(y.shape)
# Out:
# (1000, 12)
# (1000, 12)

# %%
from sklearn.model_selection import train_test_split
# la 25% de donnée utiliser pour le test et les 75% seront utiliser pour les entrainement .
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 45)
# afficher chaque label avec sonts nmbr de ligne et de colones 
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (750, 12)
# (750, 12)
# (250, 12)
# (250, 12)

# %%
from sklearn.preprocessing import MinMaxScaler

# création de lobjet mm et normaliser les données entre 0 et 1 
mm = MinMaxScaler()

# application de cette normalisation pour les entrainement et les testes effectuer avant sur l'objet  
x_train = mm.fit_transform(x_train)
x_test = mm.transform(x_test)

# %%
print(x_train)
# Out:
# [[0.         0.25       0.2        ... 0.8028169  0.76315789 0.        ]
#  [0.         0.         0.4        ... 0.28169014 0.22368421 0.        ]
#  [1.         0.5        0.6        ... 0.61971831 0.59210526 1.        ]
#  ...
#  [0.         1.         0.4        ... 0.71830986 0.73684211 1.        ]
#  [0.         0.5        0.2        ... 0.61971831 0.72368421 0.        ]
#  [1.         0.5        1.         ... 0.61971831 0.59210526 1.        ]]

# %%
print(y_train)
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 116       0               2                            1      0
# 902       0               1                            2      0
# 549       1               3                            3      1
# 327       1               1                            4      0
# 164       0               5                            3      1
# ..      ...             ...                          ...    ...
# 544       0               4                            3      1
# 892       0               1                            3      0
# 643       0               5                            2      1
# 414       0               3                            1      0
# 971       1               3                            5      1
#
#      test preparation course  math score  reading score  writing score  \
# 116                        1          75             85             82
# ...

# %%
print(x_test)
# Out:
# [[0.         1.         0.         ... 0.66197183 0.69736842 1.        ]
#  [1.         1.         0.8        ... 0.32394366 0.25       1.        ]
#  [0.         0.25       0.4        ... 0.67605634 0.65789474 1.        ]
#  ...
#  [1.         0.25       0.8        ... 0.54929577 0.56578947 1.        ]
#  [0.         0.75       1.         ... 0.81690141 0.75       0.        ]
#  [1.         0.75       1.         ... 0.43661972 0.39473684 1.        ]]

# %%
print(y_test)
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 726       0               5                            0      1
# 243       1               5                            4      1
# 342       0               2                            2      1
# 976       1               2                            4      0
# 919       1               2                            4      1
# ..      ...             ...                          ...    ...
# 166       1               3                            2      0
# 503       0               5                            0      1
# 100       1               2                            4      1
# 828       0               4                            5      0
# 399       1               4                            5      1
#
#      test preparation course  math score  reading score  writing score  \
# 726                        0          65             75             77
# ...

# %%
# visualiser le score en match
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Supposons que vous avez déjà chargé votre dataset
# Exemple d'un fichier CSV avec des colonnes comme 'math score', 'reading score', 'writing score', 
data = pd.read_csv(r"C:\Users\user\Desktop\python-projct\StudentsPerformance.csv")

# Visualisation de la distribution des scores en mathématiques
plt.figure(figsize=(6, 4))
sns.histplot(data['math score'], kde=True, color='blue', bins=20)

# Ajouter un titre et des étiquettes
plt.title('Distribution des Scores en Mathématiques', fontsize=16)
plt.xlabel('Score en Mathématiques', fontsize=14)
plt.ylabel('Fréquence', fontsize=14)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Exemple de dataset simulé
data = pd.DataFrame({
    'gender': ['female', 'male', 'female', 'male', 'female', 'male'],
    'math score': [78, 65, 89, 72, 94, 68],
    'reading score': [81, 67, 90, 74, 96, 70],
    'writing score': [85, 63, 92, 75, 97, 66]
})

# Création du boxplot pour les scores de mathématiques par genre
sns.set(style="whitegrid")  # Style de fond pour le graphique
plt.figure(figsize=(6, 6))  # Taille de la figure

sns.boxplot(x='gender', y='math score', data=data, palette='Set2')

# Titre et labels
plt.title('Distribution des scores de mathématiques par genre', fontsize=16)
plt.xlabel('Genre', fontsize=14)
plt.ylabel('Score en mathématiques', fontsize=14)

# Afficher le graphique
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13712\1557401984.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='gender', y='math score', data=data, palette='Set2')

# %%
# SVM 
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report
import seaborn as sns

# Charger le dataset
data = pd.read_csv(r"C:\Users\user\Desktop\python-projct\StudentsPerformance.csv")

# Afficher les premières lignes pour vérifier le dataset
print(data.head())

# Prétraitement : Encoder les variables catégorielles
le = LabelEncoder()
data['gender'] = le.fit_transform(data['gender'])
data['lunch'] = le.fit_transform(data['lunch'])
data['test preparation course'] = le.fit_transform(data['test preparation course'])

# Créer une variable 'pass_math' indiquant si l'étudiant a réussi en mathématiques (score >= 50)
data['math score'] = data['math score'].apply(lambda x: 1 if x >= 50 else 0)

# Sélection des caractéristiques (features) et de la cible (target)
X = data[['gender', 'reading score', 'writing score', 'lunch', 'test preparation course']]
y = data['math score']

# Diviser le dataset en ensemble d'entraînement (75%) et de test (25%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Standardiser les données
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Créer le modèle SVM
svm_model = SVC(kernel='linear', C=1)  # Utilisation d'un noyau linéaire

# Entraîner le modèle sur les données d'entraînement
svm_model.fit(X_train, y_train)

# Prédire sur les données de test
y_pred = svm_model.predict(X_test)

# Évaluer le modèle
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# Accuracy: 0.9
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.76      0.60      0.68        43
# ...

# %%
# Avec Logistic Regression!!!
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Charger le dataset
data = pd.read_csv(r"C:\Users\user\Desktop\python-projct\StudentsPerformance.csv")

# Afficher les premières lignes du dataset pour vérification
print(data.head())

# Prétraitement : Encoder les variables catégorielles
le = LabelEncoder()
data['gender'] = le.fit_transform(data['gender'])
data['lunch'] = le.fit_transform(data['lunch'])
data['test preparation course'] = le.fit_transform(data['test preparation course'])

# Créer une variable 'math score' indiquant si l'étudiant a réussi en mathématiques (score >= 50)
data['math score'] = data['math score'].apply(lambda x: 1 if x >= 50 else 0)

# Sélection des caractéristiques (features) et de la cible (target)
X = data[['gender', 'reading score', 'writing score', 'lunch', 'test preparation course']]
y = data['math score']

# Diviser le dataset en ensemble d'entraînement (75%) et de test (25%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Standardiser les données
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Créer le modèle de régression logistique
log_reg = LogisticRegression()

# Entraîner le modèle sur les données d'entraînement
log_reg.fit(X_train, y_train)

# Prédire sur les données de test
y_pred = log_reg.predict(X_test)

# Évaluer le modèle
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# Afficher la matrice de confusion
conf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Fail', 'Pass'], yticklabels=['Fail', 'Pass'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# Accuracy: 0.9
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.76      0.60      0.68        43
# ...

# %% [markdown]
# Random Forest

# %%
#Random forest 
# Importation des bibliothèques nécessaires
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Charger le dataset
data = pd.read_csv(r"C:\Users\user\Desktop\python-projct\StudentsPerformance.csv")

# Afficher les premières lignes du dataset pour vérification
print(data.head())

# Prétraitement : Encoder les variables catégorielles
le = LabelEncoder()
data['gender'] = le.fit_transform(data['gender'])
data['race/ethnicity'] = le.fit_transform(data['race/ethnicity'])
data['parental level of education'] = le.fit_transform(data['parental level of education'])
data['lunch'] = le.fit_transform(data['lunch'])
data['test preparation course'] = le.fit_transform(data['test preparation course'])

# Créer une variable 'pass_math' indiquant si l'étudiant a réussi en mathématiques (score >= 50)
data['pass_math'] = data['math score'].apply(lambda x: 1 if x >= 50 else 0)

# Sélection des caractéristiques (features) et de la cible (target)
X = data[['gender', 'race/ethnicity', 'parental level of education', 'lunch', 
          'test preparation course', 'reading score', 'writing score']]
y = data['pass_math']

# Diviser le dataset en ensemble d'entraînement (75%) et de test (25%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Standardiser les données
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Créer le modèle Random Forest
model = RandomForestClassifier(n_estimators=100, random_state=42)

# Entraîner le modèle sur les données d'entraînement
model.fit(X_train, y_train)

# Prédire sur les données de test
y_pred = model.predict(X_test)

# Évaluer le modèle
print("Accuracy :", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# Afficher la matrice de confusion
conf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Fail', 'Pass'], yticklabels=['Fail', 'Pass'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# Accuracy : 0.876
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.66      0.58      0.62        43
# ...

# %%
# Avec decision tree
# Importation des bibliothèques nécessaires
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Charger le dataset
data = pd.read_csv(r"C:\Users\user\Desktop\python-projct\StudentsPerformance.csv")

# Afficher les premières lignes du dataset pour vérification
print(data.head())

# Prétraitement : Encoder les variables catégorielles
le = LabelEncoder()
data['gender'] = le.fit_transform(data['gender'])
data['race/ethnicity'] = le.fit_transform(data['race/ethnicity'])
data['parental level of education'] = le.fit_transform(data['parental level of education'])
data['lunch'] = le.fit_transform(data['lunch'])
data['test preparation course'] = le.fit_transform(data['test preparation course'])

# Créer une variable 'pass_math' indiquant si l'étudiant a réussi en mathématiques (score >= 50)
data['pass_math'] = data['math score'].apply(lambda x: 1 if x >= 50 else 0)

# Sélection des caractéristiques (features) et de la cible (target)
X = data[['gender', 'race/ethnicity', 'parental level of education', 'lunch', 
          'test preparation course', 'reading score', 'writing score']]
y = data['pass_math']

# Diviser le dataset en ensemble d'entraînement (75%) et de test (25%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Standardiser les données
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Créer le modèle Decision Tree
model = DecisionTreeClassifier(random_state=42)

# Entraîner le modèle sur les données d'entraînement
model.fit(X_train, y_train)

# Prédire sur les données de test
y_pred = model.predict(X_test)

# Évaluer le modèle
print("Accuracy :", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# Afficher la matrice de confusion
conf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Fail', 'Pass'], yticklabels=['Fail', 'Pass'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# Accuracy : 0.876
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.64      0.63      0.64        43
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Charger le fichier CSV
data = pd.read_csv(r"C:\Users\user\Desktop\python-projct\StudentsPerformance.csv")

# Définir le seuil de réussite (par exemple, 50 points)
pass_threshold = 50

# Créer des colonnes indiquant si l'étudiant a réussi chaque test
data['pass_math'] = data['math score'] >= pass_threshold
data['pass_reading'] = data['reading score'] >= pass_threshold
data['pass_writing'] = data['writing score'] >= pass_threshold

# Calculer le taux de réussite pour chaque matière
pass_rates = {
    'Mathématiques': data['pass_math'].mean() * 100,
    'Lecture': data['pass_reading'].mean() * 100,
    'Écriture': data['pass_writing'].mean() * 100
}

# Visualiser le taux de réussite avec un graphique à barres
plt.figure(figsize=(10, 6))
plt.bar(pass_rates.keys(), pass_rates.values(), color=['blue', 'orange', 'green'])
plt.title("Taux de Réussite des Étudiants par Matière")
plt.xlabel("Matières")
plt.ylabel("Taux de Réussite (%)")
plt.ylim(0, 100)

# Afficher les valeurs sur chaque barre
for subject, rate in pass_rates.items():
    plt.text(subject, rate + 1, f"{rate:.2f}%", ha='center', fontsize=12)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Charger le fichier CSV
data = pd.read_csv(r"C:\Users\user\Desktop\python-projct\StudentsPerformance.csv")

# Définir le seuil de réussite
pass_threshold = 50

# Créer une colonne indiquant si l'étudiant a réussi toutes les matières
data['pass_all'] = (data['math score'] >= pass_threshold) & \
                   (data['reading score'] >= pass_threshold) & \
                   (data['writing score'] >= pass_threshold)

# Calculer le taux de réussite global
overall_pass_rate = data['pass_all'].mean() * 100

# Visualiser le taux de réussite global
plt.figure(figsize=(6, 6))
plt.bar(['Taux de Réussite Global'], [overall_pass_rate], color='purple')
plt.title("Taux de Réussite Global des Étudiants")
plt.ylabel("Taux de Réussite (%)")
plt.ylim(0, 100)

# Afficher la valeur sur la barre
plt.text('Taux de Réussite Global', overall_pass_rate + 1, f"{overall_pass_rate:.2f}%", ha='center', fontsize=12)

plt.show()
